# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader  = CSVLoader('metadata.csv')

# %%
loader

# %%
data = loader.load()

# %%
data
# Out:
# [Document(page_content='image_id: 10078660_15\nsplit: train\nimage_souce_url: http://www.cs.toronto.edu/~vmnih/data/mass_roads/train/sat/10078660_15.tiff\nlabel_source_url: http://www.cs.toronto.edu/~vmnih/data/mass_roads/train/map/10078660_15.tif\ntiff_image_path: tiff/train/10078660_15.tiff\ntif_label_path: tiff/train_labels/10078660_15.tif\npng_image_path: png/train/10078660_15.png\npng_label_path: png/train_labels/10078660_15.png', metadata={'source': 'metadata.csv', 'row': 0}),
#  Document(page_content='image_id: 10078675_15\nsplit: train\nimage_souce_url: http://www.cs.toronto.edu/~vmnih/data/mass_roads/train/sat/10078675_15.tiff\nlabel_source_url: http://www.cs.toronto.edu/~vmnih/data/mass_roads/train/map/10078675_15.tif\ntiff_image_path: tiff/train/10078675_15.tiff\ntif_label_path: tiff/train_labels/10078675_15.tif\npng_image_path: png/train/10078675_15.png\npng_label_path: png/train_labels/10078675_15.png', metadata={'source': 'metadata.csv', 'row': 1}),
# ...

# %%
data[0].metadata
data[0].page_content
# Out:
# 'image_id: 10078660_15\nsplit: train\nimage_souce_url: http://www.cs.toronto.edu/~vmnih/data/mass_roads/train/sat/10078660_15.tiff\nlabel_source_url: http://www.cs.toronto.edu/~vmnih/data/mass_roads/train/map/10078660_15.tif\ntiff_image_path: tiff/train/10078660_15.tiff\ntif_label_path: tiff/train_labels/10078660_15.tif\npng_image_path: png/train/10078660_15.png\npng_label_path: png/train_labels/10078660_15.png'
