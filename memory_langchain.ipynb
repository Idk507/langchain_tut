# %%
from langchain.memory import ConversationBufferMemory

# %%
memory = ConversationBufferMemory()
memory.chat_memory.add_user_message("hi!")
memory.chat_memory.add_ai_message("what's up!")

# %%
memory
# Out:
# ConversationBufferMemory(chat_memory=InMemoryChatMessageHistory(messages=[HumanMessage(content='hi!'), AIMessage(content="what's up!")]))

# %%
#Variables return memory 

memory.load_memory_variables({})
# Out:
# {'history': "Human: hi!\nAI: what's up!"}

# %%
#Memory Format :String vs List of messages 

memory = ConversationBufferMemory(memory_key="chat_history",return_messages=True)
memory.chat_memory.add_user_message("hi!")
memory.chat_memory.add_ai_message("what's up!")

# %%
memory.load_memory_variables({})
# Out:
# {'chat_history': [HumanMessage(content='hi!'),
#   AIMessage(content="what's up!")]}

# %%
#Examples 

from langchain_openai import OpenAI
from langchain_core.prompts import PromptTemplate
from langchain.chains.llm import LLMChain 
from langchain.memory import ConversationBufferMemory
from langchain_community.llms.huggingface_endpoint import HuggingFaceEndpoint

import os

# %%
os.environ["HUGGINGFACEHUB_API_TOKEN"] = "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"

# %%
llm_hf = HuggingFaceEndpoint(repo_id="google/flan-t5-xxl",temperature=0.1)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to C:\Users\dhanu\.cache\huggingface\token
# Login successful

# %%
memory = ConversationBufferMemory(memory_key="Chat_history_ex")
memory.chat_memory.add_user_message("Hello!")
memory.chat_memory.add_ai_message("Hi,I am an AI Assistant ,How are you?")

# %%
template = """ 

You are a nice chatbot having a conversation with a human. 
Previous conversation : {Chat_history_ex}

New human question : {question} 
Response : 
"""

# %%
prompt = PromptTemplate.from_template(template)

prompt.format
# Out:
# <bound method PromptTemplate.format of PromptTemplate(input_variables=['Chat_history_ex', 'question'], template=' \n\nYou are a nice chatbot having a conversation with a human. \nPrevious conversation : {Chat_history_ex}\n\nNew human question : {question} \nResponse : \n')>

# %%
conversation_chain = LLMChain( 
    llm=llm_hf,prompt=prompt,verbose=True ,memory=memory
)

# %%
conversation_chain
# Out:
# LLMChain(memory=ConversationBufferMemory(chat_memory=InMemoryChatMessageHistory(messages=[HumanMessage(content='Hello!'), AIMessage(content='Hi,I am an AI Assistant ,How are you?')]), memory_key='Chat_history_ex'), verbose=True, prompt=PromptTemplate(input_variables=['Chat_history_ex', 'question'], template=' \n\nYou are a nice chatbot having a conversation with a human. \nPrevious conversation : {Chat_history_ex}\n\nNew human question : {question} \nResponse : \n'), llm=HuggingFaceEndpoint(repo_id='google/flan-t5-xxl', temperature=0.1, model='google/flan-t5-xxl', client=<InferenceClient(model='google/flan-t5-xxl', timeout=120)>, async_client=<InferenceClient(model='google/flan-t5-xxl', timeout=120)>))

# %%
conversation_chain({"question":"hi"})
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#
# You are a nice chatbot having a conversation with a human.
# Previous conversation : Human: Hello!
# AI: Hi,I am an AI Assistant ,How are you?
#
# New human question : hi
# Response :
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\dhanu\.conda\envs\lm_python\lib\site-packages\huggingface_hub\utils\_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File c:\Users\dhanu\.conda\envs\lm_python\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 503 Server Error: Service Unavailable for url: https://api-inference.huggingface.co/models/google/flan-t5-xxl
#
# ...

# %%
conversation_chain({"question":"What is USA?"})
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#
# You are a nice chatbot having a conversation with a human.
# Previous conversation : Human: Hello!
# AI: Hi,I am an AI Assistant ,How are you?
#
# New human question : What is USA?
# Response :
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\dhanu\.conda\envs\lm_python\lib\site-packages\huggingface_hub\utils\_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File c:\Users\dhanu\.conda\envs\lm_python\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api-inference.huggingface.co/models/google/flan-t5-xxl
#
# ...

# %%
conversation_chain({"question": "who is president of USA?"})
# Out:
# > Entering new LLMChain chain...
# Prompt after formatting:
#
#
# You are a nice chatbot having a conversation with a human.
# Previous conversation : Human: Hello!
# AI: Hi,I am an AI Assistant ,How are you?
#
# New human question : who is president of USA?
# Response :
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\dhanu\.conda\envs\lm_python\lib\site-packages\huggingface_hub\utils\_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File c:\Users\dhanu\.conda\envs\lm_python\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# ...

# %%
memory.load_memory_variables({})
# Out:
# {'Chat_history_ex': 'Human: Hello!\nAI: Hi,I am an AI Assistant ,How are you?'}

# %%
#chat Messages 

from langchain.memory import ChatMessageHistory

history = ChatMessageHistory()

history.add_user_message("hi!")

history.add_ai_message("whats up?")

# %%
history.messages
# Out:
# [HumanMessage(content='hi!'), AIMessage(content='whats up?')]
